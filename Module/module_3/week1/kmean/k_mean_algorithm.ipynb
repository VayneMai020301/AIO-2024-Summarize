# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs

SEED  = 42 
np.random.seed(SEED)

# %% [markdown]
# ### Create data point

# %% [markdown]
# #### Sample test

# %%
def create_data_point(num_class = 5, num_points_per_class = 20):
    data = []
    for class_label in range(num_class):
        x = np.random.normal(loc=class_label * 3, scale=1.0, size=num_points_per_class)
        y = np.random.normal(loc=class_label * 3, scale=1.0, size=num_points_per_class)
        data.append(pd.DataFrame({'x': x, 'y': y, 'class': class_label}))
    
    df = pd.concat(data, ignore_index=True)
    return df
df = create_data_point(num_points_per_class=100)

# %%
df.head()
# Out:
#           x         y  class
# 0  0.496714 -1.415371      0
# 1 -0.138264 -0.420645      0
# 2  0.647689 -0.342715      0
# 3  1.523030 -0.802277      0
# 4 -0.234153 -0.161286      0

# %% [markdown]
# #### Function Building

# %%
def create_sample(num_classes = 2,
                  samples_per_class = 220,
                  seed = None)->pd.DataFrame:
    

    X, y = make_blobs(n_samples = num_classes * samples_per_class, 
                    centers = num_classes, 
                    cluster_std = 1.1, 
                    random_state = seed)
    df = pd.DataFrame(X, columns=['x', 'y'])
    df['class'] = y
    return df

# %% [markdown]
# ### Data Point Visualization

# %%
def visual(df):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x='x', y='y', hue='class', palette='tab10', s=50, alpha=0.7, edgecolor=None)
    plt.title('2D Data Points for Clustering')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend(title='Class')
    plt.savefig('k-mean.png', dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.show()

visual(df)

# %% [markdown]
# ### Take data sample based on class

# %%
class_0 = df[df['class']==0]
print(class_0.head())
# Out:
#           x         y  class
# 0  0.496714 -1.415371      0
# 1 -0.138264 -0.420645      0
# 2  0.647689 -0.342715      0
# 3  1.523030 -0.802277      0
# 4 -0.234153 -0.161286      0

# %%
class_1 = df[df['class']==1]
print(class_1.head())
# Out:
#             x         y  class
# 100  3.357787  2.171005      1
# 101  3.560785  2.439819      1
# 102  4.083051  3.747294      1
# 103  4.053802  3.610370      1
# 104  1.622331  2.979098      1

# %%
class_1 = df[df['class']==2]
print(class_1.head())
# Out:
#             x         y  class
# 200  4.405572  6.926178      2
# 201  5.400625  7.909417      2
# 202  6.005244  4.601432      2
# 203  6.046981  6.562969      2
# 204  5.549935  5.349357      2

# %% [markdown]
# ### K-Mean Algorithm

# %% [markdown]
# #### Build-up step-by-step

# %% [markdown]
# ##### Convert DataFrame Point to numpy Point

# %%
x_point = df.to_numpy()[:,0]
y_point = df.to_numpy()[:,1]
print(x_point.shape)
print(y_point.shape)
print(x_point[0],y_point[0])
# Out:
# (500,)
# (500,)
# 0.4967141530112327 -1.4153707420504142

# %%
list_point = np.column_stack((x_point, y_point))
array_points = np.array(list_point)
array_points_extended = np.array(list_point)[:, np.newaxis] 

print(array_points)
print(array_points.shape)
print(array_points_extended.shape)
# Out:
# [[ 4.96714153e-01 -1.41537074e+00]
#  [-1.38264301e-01 -4.20645323e-01]
#  [ 6.47688538e-01 -3.42714517e-01]
#  [ 1.44553001e+01  1.13080919e+01]
#  [ 1.13622600e+01  1.19544140e+01]
#  [ 1.14690030e+01  1.22433394e+01]
#  [ 1.13768595e+01  1.17587639e+01]
#  [ 1.14445229e+01  1.23520554e+01]
#  [ 1.13626129e+01  1.07484606e+01]
#  [ 1.31890165e+01  1.34437646e+01]
#  [ 1.34205042e+01  1.19178488e+01]
#  [ 1.14292537e+01  1.31172958e+01]
#  [ 1.11676444e+01  1.23427253e+01]
#  [ 1.24714156e+01  1.24567532e+01]
#  [ 1.14477770e+01  1.25697673e+01]
#  [ 1.26329318e+01  1.24477086e+01]
#  [ 1.22029230e+01  1.26427228e+01]
#  [ 1.04842559e+01  1.33291525e+01]
#  [ 1.35475052e+01  1.21965212e+01]
#  [ 1.37958777e+01  1.27090038e+01]
#  [ 1.13872113e+01  1.19102643e+01]
#  [ 1.16122984e+01  1.34401172e+01]
#  [ 1.22858654e+01  1.13236077e+01]
#  [ 1.23344568e+01  1.38009404e+01]
#  [ 1.26585443e+01  1.19598420e+01]
#  [ 1.40102045e+01  1.05692249e+01]
#  [ 1.18230528e+01  1.21281044e+01]
#  [ 1.12017028e+01  1.13189483e+01]
#  [ 1.06206808e+01  1.28406435e+01]
#  [ 1.12690700e+01  1.13473760e+01]
#  [ 1.19668730e+01  1.15538166e+01]
#  [ 1.37945579e+01  1.01104593e+01]
#  [ 1.14823887e+01  1.15476937e+01]
#  [ 1.22237880e+01  9.57612067e+00]
#  [ 1.19835771e+01  1.04160972e+01]
#  [ 1.31883933e+01  1.27604147e+01]
#  [ 1.45269324e+01  1.27858002e+01]
#  [ 1.14691312e+01  1.24254576e+01]
#  [ 1.15105606e+01  1.10330239e+01]
#  [ 1.30441609e+01  1.19522886e+01]
#  [ 1.26818915e+01  1.19963975e+01]
#  [ 1.38467073e+01  1.08416353e+01]
#  [ 1.25839282e+01  1.35033983e+01]
#  [ 1.16407079e+01  1.28773623e+01]
#  [ 1.25906548e+01  1.17790358e+01]
#  [ 1.31087036e+01  1.20268858e+01]
#  [ 1.28204822e+01  1.22083828e+01]
#  [ 1.25072740e+01  9.95826513e+00]
#  [ 1.30666747e+01  1.17528226e+01]
#  [ 1.31692956e+01  1.13180158e+01]
#  [ 1.33821590e+01  1.09983800e+01]
#  [ 1.26487099e+01  1.17188997e+01]
#  [ 1.18328819e+01  1.37976865e+01]
#  [ 1.21467137e+01  1.26408429e+01]
#  [ 1.32065090e+01  1.14288210e+01]
#  [ 1.11830643e+01  1.25725828e+01]]
# (500, 2)
# (500, 1, 2)

# %% [markdown]
# ##### Randomly Create Centroid Point

# %%
k_assumtion = 2
centroids = array_points[np.random.choice(array_points.shape[0], k_assumtion, replace=False)]
centroids
# Out:
# array([[10.84895609,  8.07676675],
#        [ 9.71095997,  8.92983429]])

# %% [markdown]
# ##### Distance Calculated and assign labels between centroid point to each sample in data

# %%
distances = np.linalg.norm(array_points[0:, np.newaxis]- centroids, axis=2)
print(distances)
labels = np.argmin(distances, axis=1)
#  [ 2.47957483  2.06938218]
#  [ 1.76650141  1.75312477]
#  [ 4.50379706  4.17174806]
#  [ 3.69099003  3.60027932]
#  [ 3.96483904  4.35203371]
#  [ 4.63410588  3.99288117]
#  [ 4.68230299  4.65803339]
#  [ 3.48740475  3.253661  ]
#  [ 2.86331134  2.86693314]
#  [ 5.13151296  4.93241723]
#  [ 4.57352212  3.89890081]
#  [ 4.12006007  3.99542546]
#  [ 5.91837804  5.49585216]
#  [ 3.29264827  3.4259331 ]
#  [ 2.79700129  3.00550734]
#  [ 4.8422288   5.3070588 ]
#  [ 3.91147401  3.44599393]
#  [ 4.21245608  3.75100412]
#  [ 3.71964854  3.28299621]
#  [ 4.31657188  3.83625308]
#  [ 2.7206233   2.45669674]
#  [ 5.85495933  5.69845982]
#  [ 4.62242051  4.76329189]
#  [ 5.07382289  4.52629733]
#  [ 4.27784583  3.71076205]
#  [ 4.67083035  4.47875789]
#  [ 4.53272988  4.03306898]
#  [ 4.72098524  4.5731126 ]
#  [ 4.76247632  4.47162394]
#  [ 5.26503206  4.46676478]
#  [ 4.92489022  5.03888108]
#  [ 5.49016998  5.56495054]
#  [ 3.8711009   3.41947096]
#  [ 5.41739972  4.89466445]
#  [ 3.55058931  3.51572028]
#  [ 5.913787    5.53266759]
#  [ 4.28402651  4.22719768]
#  [ 4.02564769  4.60120696]
#  [ 4.16679747  3.83273634]
#  [ 3.26131441  2.81605753]
#  [ 4.7693429   4.01522366]
#  [ 3.29748095  2.87614582]
#  [ 3.65234359  3.46040846]
#  [ 3.57945178  4.25084075]
#  [ 3.52825319  3.16087766]
#  [ 2.03426272  2.59460798]
#  [ 2.59996763  2.71546792]
#  [ 5.23541058  5.17357597]
#  [ 5.97515736  6.16944596]
#  [ 4.3926904   3.91286957]
#  [ 3.0293855   2.76802613]
#  [ 4.45405365  4.49949537]
#  [ 4.32702635  4.26968896]
#  [ 4.07811361  4.55624729]
#  [ 5.6972325   5.40105861]
#  [ 4.86544843  4.39396227]
#  [ 4.09149249  4.05099888]
#  [ 4.55081306  4.59743298]
#  [ 4.57789977  4.51862908]
#  [ 2.50799811  2.97943658]
#  [ 4.29321121  4.38521201]
#  [ 3.98618495  4.20279621]
#  [ 3.86690326  4.21385614]
#  [ 4.06254184  4.05083454]
#  [ 5.80491456  5.31022958]
#  [ 4.74499373  4.43897294]
#  [ 4.09808776  4.29695211]
#  [ 4.50821362  3.9289576 ]]
# ''

# %% [markdown]
# ##### Update cluster's centroid point by calculate mean of X-coordinate and Y-coordinate

# %%
new_centroids = np.array([array_points[labels == i].mean(axis=0) for i in range(k_assumtion)])
new_centroids
# Out:
# array([[11.82375111,  9.50261019],
#        [ 5.43060158,  5.64443832]])

# %%
distances = np.linalg.norm(array_points[0:, np.newaxis]- centroids, axis=2)
labels = np.argmin(distances, axis=1)
new_centroids = np.array([array_points[labels == i].mean(axis=0) for i in range(k_assumtion)])
print(new_centroids)
if np.all(new_centroids == centroids):
    print(f'Finish')
else:
    centroids = new_centroids
    print("continue")
# Out:
# [[11.82375111  9.50261019]
#  [ 5.43060158  5.64443832]]
# continue

# %%
print(centroids)
# Out:
# [[11.82375111  9.50261019]
#  [ 5.43060158  5.64443832]]

# %% [markdown]
# #### Class Buidling

# %%
class KMean:
    def __init__(self, df: pd.DataFrame,
                 k = 5, 
                 max_iter = 1000) -> None :
        self.__df = df 
        self.__k = k
        self.__max_iter =max_iter
        self.__x_point = self.__df.to_numpy()[:,0]
        self.__y_point = self.__df.to_numpy()[:,1]
        self.__list_point  = np.column_stack((self.__x_point, self.__y_point))
        self.__array_points = np.array(self.__list_point)
        self.__array_points_extend = np.array(self.__list_point)[0:, np.newaxis] 
        self.wcss = []
        self.total_wcss = 0

    def __visual(self,centroids_df, centroids):
        combined_df = pd.concat([self.__df,centroids_df ], ignore_index=True)
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=self.__df, x='x', y='y', hue='class', palette='tab10', s=50, alpha=0.7, markers="o", edgecolor=None)
        sns.scatterplot(data=combined_df[combined_df['class'] == 'centroid cluster'], x='x', y='y', color='black', s=300, marker='x', label='Centroid')
        plt.title('2D Data Points for Clustering')
        plt.xlabel('X')
        plt.ylabel('Y')
        plt.legend(title='Class')
        plt.savefig('kmean-cluster.png', dpi=300, bbox_inches='tight', pad_inches=0.1)
        plt.show()

    def cluster(self,visual  = False) -> list[pd.DataFrame, np.array,np.array] :
        """
            Return DataFrame of centroid point
            * Args:
            * Parameter:
            distances: distances matrix, with each row in matrix express disance from 1 point to centroid point
                [(sample_point -> centroid 1),  (sample_point -> centroid 2), (sample_point -> centroid 3))
            >>> distances
            array([[2.6878189  8.66977841 9.27567322]
                [2.59545772 8.84237138 9.23191662]
                [2.63731041 9.19806121 9.21298198]
                ...
                [7.26146886 1.08849996 3.54933464]
                [6.59683898 4.85696506 0.69884407]
                [6.52375225 3.53811902 0.67576247]])
            >>> labels: given cluster indicator
            array([0 0 0 ... 1 2 2])
        """
        '''
            self.__array_points.shape[0]: return number of point 
        '''
        number_row_of_centroid = self.__array_points.shape[0]
        centroids = self.__array_points[np.random.choice(number_row_of_centroid, self.__k, replace=False)]

        for _ in range(self.__max_iter):
            distances = np.linalg.norm(self.__array_points_extend  - centroids, axis=2)
            labels = np.argmin(distances, axis=1)
            new_centroids = np.array([self.__array_points[labels == i].mean(axis=0) for i in range(self.__k)])
            WCSS = np.sum([np.sum(np.square(self.__array_points[labels == i] - new_centroids[i])) for i in range(self.__k)])
            self.wcss.append(WCSS)
            self.total_wcss+=WCSS
            print(f'Iteration {_}: WCSS: {round(WCSS,3)}')
            if np.all(new_centroids == centroids):
                break
            centroids = new_centroids
            
        centroid_df = pd.DataFrame({ 'x': centroids[:,0], 'y': centroids[:,1],'class':"centroid cluster"})

        if visual:
            self.__visual(centroid_df,centroids)
           
        return centroid_df

# %%
df = create_sample(num_classes = 5, samples_per_class = 300)
#df =  create_data_point(num_points_per_class=100)
kmean = KMean(df, k = 5, max_iter = 1000)
centroids_df = kmean.cluster(visual = True)
# Out:
# Iteration 0: WCSS: 6659.428
# Iteration 1: WCSS: 4561.84
# Iteration 2: WCSS: 3895.767
# Iteration 3: WCSS: 3698.137
# Iteration 4: WCSS: 3664.427
# Iteration 5: WCSS: 3657.524
# Iteration 6: WCSS: 3655.661
# Iteration 7: WCSS: 3655.571
# Iteration 8: WCSS: 3655.501
# Iteration 9: WCSS: 3655.422
# Iteration 10: WCSS: 3655.422

# %% [markdown]
# ### Using elbow to evaluation K value

# %%
centroids_df
# Out:
#           x         y             class
# 0       NaN       NaN  centroid cluster
# 1 -0.640671  0.654683  centroid cluster
# 2       NaN       NaN  centroid cluster
# 3       NaN       NaN  centroid cluster
# 4       NaN       NaN  centroid cluster

# %% [markdown]
# #### Visualize Controid DataFrame and Point DataFrame

# %%
combined_df = pd.concat([df,centroids_df ], ignore_index=True)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='x', y='y', hue='class', palette='tab10', s=50, alpha=0.7, markers="o", edgecolor=None)
sns.scatterplot(data=combined_df[combined_df['class'] == 'centroid cluster'], x='x', y='y', color='black', s=300, 
                        marker='x', label='Centroid')
plt.title('2D Data Points for Clustering')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(title='Class')
plt.savefig('centroid.png', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ### Visualization and observation Elbow to choise K

# %%
df = create_sample(num_classes = 5, 
                   samples_per_class = 300,
                   seed =42)

num_k = 10 
list_wcss = []
for i in range(1,num_k+1):
    kmean = KMean(df, k = i, max_iter = 1000)
    kmean.cluster()
    list_wcss.append(kmean.total_wcss)

print(f"wcss là : {list_wcss}")
# Out:
# Iteration 0: WCSS: 89429.515
# Iteration 1: WCSS: 89429.515
# Iteration 0: WCSS: 52918.868
# Iteration 1: WCSS: 52376.45
# Iteration 2: WCSS: 52364.791
# Iteration 3: WCSS: 52364.791
# Iteration 0: WCSS: 46275.935
# Iteration 1: WCSS: 41569.878
# Iteration 2: WCSS: 19209.111
# Iteration 3: WCSS: 17030.077
# Iteration 4: WCSS: 13814.492
# Iteration 5: WCSS: 11889.564
# Iteration 6: WCSS: 11796.979
# Iteration 7: WCSS: 11796.979
# Iteration 0: WCSS: 28464.741
# Iteration 1: WCSS: 9090.041
# Iteration 2: WCSS: 5582.963
# Iteration 3: WCSS: 5252.822
# Iteration 4: WCSS: 5249.206
# Iteration 5: WCSS: 5249.206
# Iteration 0: WCSS: 5521.482
# Iteration 1: WCSS: 4232.425
# Iteration 2: WCSS: 3531.337
# Iteration 3: WCSS: 3425.913
# Iteration 4: WCSS: 3413.616
# Iteration 5: WCSS: 3411.104
# Iteration 6: WCSS: 3410.831
# Iteration 7: WCSS: 3410.831
# Iteration 0: WCSS: 9560.757
# Iteration 1: WCSS: 9240.733
# Iteration 2: WCSS: 8966.878
# Iteration 3: WCSS: 8116.6
# Iteration 4: WCSS: 4969.621
# Iteration 5: WCSS: 3209.069
# Iteration 6: WCSS: 3168.866
